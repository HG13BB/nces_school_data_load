# %%
import pandas as pd
import os
import sqlalchemy 
import glob

# %%
#connection to the open payments in data in mysql
constr = 'mysql+mysqlconnector://root:mysqlroot@localhost:3306/school_statistics'
engine = sqlalchemy.create_engine(constr,echo=False)

# %%
#short query to test connection: This needs to be run every time in order to establish the connectin successfully.
pd.read_sql_query(con=engine, sql = 'SELECT * FROM school_statistics.edfacts_ethnic_groups')
# Out:
#    Abbr                           Descr MyUnknownColumn
# 0   ALL                    All Students
# 1   MAM  American Indian/Alaska Native
# 2   MAS         Asian/Pacific Islander
# 3   MHI                       Hispanic
# 4   MBL                          Black
# 5   MWH                          White
# 6   MTR               Two or More Races
# 7   CWD      Children with disabilities
# 8   ECD     Economically disadvantaged
# 9   LEP     Limited English proficient
# 10    F                         Female
# 11    M                           Male
# 12  HOM                        Homeless
# 13  MIG                        Migrant
# 14  FCS              Foster Care Status
# 15  MIL              Military Connected
# 16

# %%
eg_query = """
SELECT 

Abbr
,Descr

FROM school_statistics.edfacts_ethnic_groups

"""

eth_grp = pd.read_sql_query(con=engine, sql = eg_query)

eth_grp = eth_grp[eth_grp['Descr'] != '']

eth_grp.columns = ['dem_grp','Demographic_Group']

eth_grp
# Out:
#    dem_grp               Demographic_Group
# 0      ALL                    All Students
# 1      MAM  American Indian/Alaska Native
# 2      MAS         Asian/Pacific Islander
# 3      MHI                       Hispanic
# 4      MBL                          Black
# 5      MWH                          White
# 6      MTR               Two or More Races
# 7      CWD      Children with disabilities
# 8      ECD     Economically disadvantaged
# 9      LEP     Limited English proficient
# 10       F                         Female
# 11       M                           Male
# 12     HOM                        Homeless
# 13     MIG                        Migrant
# 14     FCS              Foster Care Status
# 15     MIL              Military Connected

# %%
prof_results = pd.read_sql_query('select * from st_dem_grp_scores',con=engine)

# %%
prof_results = prof_results.merge(eth_grp, how='left', on = 'dem_grp')
prof_results
# Out:
#        ST dem_grp schl_yr testtype  numstudents  pctprof_weight  \
# 0      AL     ALL    0910      MTH     365212.0      29028854.0
# 1      AL     ECD    0910      MTH     203654.0      14611162.5
# 2      AL     LEP    0910      MTH       7716.0        380636.5
# 3      AL     MAM    0910      MTH       3278.0        198736.5
# 4      AL     MAS    0910      MTH       4582.0        273076.5
# ...    ..     ...     ...      ...          ...             ...
# 12370  VI     MAS    1819      RLA         31.0             0.0
# 12371  VI     MBL    1819      RLA       4385.0        325551.0
# 12372  VI     MHI    1819      RLA       1196.0         94185.5
# 12373  VI     MTR    1819      RLA         14.0             0.0
# 12374  VI     MWH    1819      RLA         89.0          2040.0
#
#        pctprof_weighted               Demographic_Group
# 0             79.484940                    All Students
# 1             71.745031     Economically disadvantaged
# 2             49.330806     Limited English proficient
# 3             60.627364  American Indian/Alaska Native
# 4             59.597665         Asian/Pacific Islander
# ...                 ...                             ...
# 12370          0.000000         Asian/Pacific Islander
# 12371         74.241961                          Black
# 12372         78.750418                       Hispanic
# 12373          0.000000               Two or More Races
# 12374         22.921348                          White
#
# [12375 rows x 8 columns]

# %%
prof_results_all = prof_results[prof_results['dem_grp'] == 'ALL']

# %%
prof_results_all['prev_yr_score'] = prof_results_all.groupby(['ST','testtype'])['pctprof_weighted'].shift(1)
# Out:
# <ipython-input-8-54d484d86a63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prof_results_all['prev_yr_score'] = prof_results_all.groupby(['ST','testtype'])['pctprof_weighted'].shift(1)

# %%
prof_results_all['YoY Change'] = prof_results_all['pctprof_weighted'] - prof_results_all['prev_yr_score']
# Out:
# <ipython-input-9-ad1220e749c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prof_results_all['YoY Change'] = prof_results_all['pctprof_weighted'] - prof_results_all['prev_yr_score']

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
a4_dims = (20, 10)
fig, ax = pyplot.subplots(figsize=a4_dims)

data =  prof_results_all
sns.lineplot(x=data['schl_yr'],y=data['pctprof_weighted'],ax=ax,color='b')
#sns.lineplot(x=data['schl_yr'],y=data['YoY Change'],ax=ax,color='b')

# %%
a4_dims = (20, 10)
fig, ax = pyplot.subplots(figsize=a4_dims)

data =  prof_results_all#[prof_results_all['ST'] == 'MN']
sns.boxplot(x=data['schl_yr'],y=data['pctprof_weighted'],ax=ax, color = 'blue')

# %%
grid = sns.FacetGrid(prof_results_all, col="schl_yr",height=4,col_wrap=4)
grid.map(sns.scatterplot,'prev_yr_score','pctprof_weighted')

# %%
pre = list(prof_results_all['schl_yr'].drop_duplicates())[:-4]
post = list(prof_results_all['schl_yr'].drop_duplicates())[-4:]

# %%
post
# Out:
# ['1516', '1617', '1718', '1819']

# %%
def prepost(data,year):    
    
    #function to split data into two groups
    yearindex = list(prof_results_all['schl_yr'].drop_duplicates()).index(year)
    
    #create two lists of values
    pre = list(prof_results_all['schl_yr'].drop_duplicates())[:yearindex]
    post = list(prof_results_all['schl_yr'].drop_duplicates())[yearindex:]
    
    data['prepost'] = data['schl_yr'].isin(post)
      
    return sns.lmplot(data=data,x='prev_yr_score',y='pctprof_weighted',col='prepost')

# %%
def prepost_data(data,year):    
    
    #function to split data into two groups
    yearindex = list(prof_results_all['schl_yr'].drop_duplicates()).index(year)
    
    #create two lists of values
    pre = list(prof_results_all['schl_yr'].drop_duplicates())[:yearindex]
    post = list(prof_results_all['schl_yr'].drop_duplicates())[yearindex:]
    
    data['prepost'] = data['schl_yr'].isin(post)
      
    return data

# %%
import seaborn as sns
from scipy import stats

split = '1718'

scores = prepost_data(prof_results_all,split)

g = sns.lmplot(x='prev_yr_score', y='pctprof_weighted', data=scores, 
               col='prepost', height=10, aspect=.8)

def annotate(data, **kws):
    r, p = stats.pearsonr(data['prev_yr_score'], data['pctprof_weighted'])
    ax = pyplot.gca()
    ax.text(.10, .8, 'r={:.2f}'.format(r),
            transform=ax.transAxes,size='x-large')
    

    
g.map_dataframe(annotate)

g.fig.suptitle('Split at {} School Year'.format(split) ,
               fontsize = 'x-large',
                  y=1.1,
              fontweight='bold')
pyplot.show()
# Out:
# <ipython-input-17-9d9998118535>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['prepost'] = data['schl_yr'].isin(post)

# %%
split = '1617'

scores = prepost_data(prof_results_all,split)


g = sns.lmplot(x='prev_yr_score', y='pctprof_weighted', data=scores, 
               col='prepost', height=10, aspect=.8)

def annotate(data, **kws):
    r, p = stats.pearsonr(data['prev_yr_score'], data['pctprof_weighted'])
    ax = pyplot.gca()
    ax.text(.05, .8, 'r={:.2f}'.format(r),
            transform=ax.transAxes,size='x-large')
    
g.map_dataframe(annotate)

g.fig.suptitle('Split at {} School Year'.format(split) ,
               fontsize = 'x-large',
                  y=1.1,
              fontweight='bold')

pyplot.show()
# Out:
# <ipython-input-17-9d9998118535>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['prepost'] = data['schl_yr'].isin(post)

# %%
prepost_data(prof_results_all,'1718')
# Out:
# <ipython-input-17-9d9998118535>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['prepost'] = data['schl_yr'].isin(post)
#        ST dem_grp schl_yr testtype  numstudents  pctprof_weight  \
# 0      AL     ALL    0910      MTH     365212.0      29028854.0
# 9      AL     ALL    1011      MTH     367417.0      29873002.5
# 21     AL     ALL    1112      MTH     368967.0      30445194.0
# 33     AL     ALL    1213      MTH     370997.0      30099342.5
# 45     AL     ALL    1314      MTH     375721.0      14351885.0
# ...    ..     ...     ...      ...          ...             ...
# 12326  VI     ALL    1314      RLA       7225.0        341818.5
# 12336  VI     ALL    1415      RLA       6818.0        117054.5
# 12346  VI     ALL    1516      RLA       6978.0        137841.5
# 12356  VI     ALL    1617      RLA       6782.0        539788.0
# 12365  VI     ALL    1819      RLA       5721.0        430673.0
#
#        pctprof_weighted Demographic_Group  prev_yr_score  YoY Change  prepost
# 0             79.484940      All Students            NaN         NaN    False
# 9             81.305444      All Students      79.484940    1.820504    False
# 21            82.514680      All Students      81.305444    1.209236    False
# 33            81.130959      All Students      82.514680   -1.383721    False
# 45            38.198251      All Students      81.130959  -42.932708    False
# ...                 ...               ...            ...         ...      ...
# 12326         47.310519      All Students      46.878115    0.432404    False
# 12336         17.168451      All Students      47.310519  -30.142068    False
# 12346         19.753726      All Students      17.168451    2.585275    False
# 12356         79.591271      All Students      19.753726   59.837545    False
# 12365         75.279322      All Students      79.591271   -4.311949     True
#
# [1042 rows x 11 columns]

# %%
mth = prof_results_all[prof_results_all['testtype'] == 'MTH']

score_ct_mth = pd.crosstab(mth['ST'],columns=mth['schl_yr'],values=mth['pctprof_weighted'],\
           aggfunc='sum')

RLA = prof_results_all[prof_results_all['testtype'] == 'RLA']

score_ct_rla = pd.crosstab(RLA['ST'],columns=RLA['schl_yr'],values=RLA['pctprof_weighted'],\
           aggfunc='sum')

# %%
score_ct_rla
# Out:
# schl_yr       0910       1011       1112       1213       1314       1415  \
# ST
# AK       81.108949  77.635218  79.319338  77.587169  79.249187  35.183750
# AL       83.852370  85.672088  86.353615  86.393766  42.554322  40.906336
# AR       72.335443  73.507924  80.477681  78.639650  77.123798  34.202721
# AZ       75.010374  77.659493  77.986880  78.896518  79.278068  37.514429
# BI       38.967636  41.196367  41.736723        NaN        NaN        NaN
# CA       54.110620        NaN  58.252278  56.886987  57.800501  44.335423
# CO       89.948871        NaN  70.130953  70.192677  69.421333  39.992039
# CT       78.475928        NaN  80.750481  79.952023  72.013086  55.483732
# DC       48.087516  49.842890  47.214546  51.864083  50.650813  25.703606
# DE       75.492440  62.446111  74.388993  73.540249  73.138697  52.395196
# FL       62.246487  62.278714  57.324525  57.910372  58.400172  53.132251
# GA       90.708428  91.126643  93.645596  94.302272  94.921396  38.688515
# HI       67.370230  66.565095  71.059300  72.175581  69.188882  48.576142
# IA       74.869998  76.462167  71.904097  72.490569  75.775648  76.352525
# ID       87.406236  88.330199  88.910638  88.985416  60.132868  51.108922
# IL       74.834904  75.403183  75.686581  59.149079  57.249562  38.126567
# IN       75.114471  77.696740  78.875674  78.713233  80.064396  68.614585
# KS       86.476418  87.944289  86.898422  84.709193        NaN  41.957763
# KY       72.061572  72.167629  48.458920  50.640601  54.525473  54.755970
# LA       67.846815  68.793259  73.196048  72.847007  70.653724  71.175024
# MA       69.367518  70.634542  70.403500  69.895116  69.954292  70.240171
# MD       85.005196  85.991408  85.709948  85.469686  82.786549  45.448249
# ME       66.723555  67.204668  68.885653  68.323687  66.710570  48.364306
# MI       83.908734  82.491172  65.687642  66.748972  68.123150  50.026757
# MN       72.638549  74.094759  75.671614  57.931348  59.064940  59.742789
# MO       54.533684  55.176094  55.452974  55.220480  52.767288  59.811677
# MS       51.649199  53.936268  56.983965  59.411783  56.867579  32.783715
# MT       82.916613  83.630835  84.986572  82.911274  22.605375  47.751504
# NC       69.650547  70.468192  73.114902  45.203832  46.035706  46.123529
# ND       76.369306  74.903644  73.833250  73.190572  72.667688  46.291164
# NE       68.715840  71.840135  74.008966  76.642728  77.434781  79.494267
# NH       77.007138  76.770950  78.704789  78.329647  76.860082  58.658777
# NJ       70.072547  70.376982  69.852672  70.440680  70.346688  47.043040
# NM       53.365650  49.882527  50.789663  50.702104  48.969526  26.624297
# NV       67.825986  61.592091  62.782183  64.168392  65.923553        NaN
# NY       75.717062  59.590317  61.767371  40.529168  36.837726  42.595577
# OH       82.410591  83.177024  83.362828  83.978300  84.129783  74.783603
# OK       67.057131  68.797050  69.227752  70.286246  69.260947  70.341025
# OR       78.047216  81.107544  73.795267  72.468119  72.242758  55.998742
# PA       73.066538  73.995462  72.105670  70.410057  70.268404  62.116770
# PR       40.068441  43.904435  46.025066  47.533700  45.494333  43.117560
# RI       71.202203  72.439045  73.617289  73.788759  73.418064  36.649038
# SC       81.473667  71.526665  72.500357  74.578175  72.268958  41.709143
# SD       75.201233  75.413075  75.404615  74.000299  39.902039  49.276848
# TN       49.190086  52.651596  55.029364  54.127323  51.802009  51.368031
# TX       88.905532  88.512362  88.452133  78.509362  75.275493  73.571078
# UT       80.726351  81.309639  82.876704  82.891421  42.408327  43.631777
# VA       89.005192  88.499058  89.032172  74.750228  74.479352  78.985087
# VI             NaN        NaN  45.418805  46.878115  47.310519  17.168451
# VT       70.970652  70.441925  71.549018  70.785067  69.443607  52.017826
# WA       69.626505  69.703964  71.880255  72.633379  73.757749  55.642806
# WI       82.556568  83.898459  36.373997  36.651923  37.027527  52.375044
# WV       42.386076  48.251528  48.658587  48.157894  46.556638  46.026578
# WY             NaN  74.657101  72.551082  74.368698  53.006243  54.420926
#
# schl_yr       1516       1617       1718       1819
# ST
# AK             NaN  38.724111  42.734853  39.569760
# AL       38.551373  39.118867  45.944323  45.384786
# AR       48.312131  52.714974  43.995135  44.613275
# AZ       39.857673  41.938555  43.561477  45.342161
# BI       31.354870  30.434659        NaN  15.884246
# CA       47.663712  48.321486  49.740933  50.784138
# CO       40.127214  42.183351  44.225460  47.237335
# CT       57.665397  56.546266  57.471476  57.553166
# DC       27.114545  30.753574  33.552770  37.892430
# DE       54.828081  54.473289  53.368661  52.349109
# FL       52.351884  53.813461  54.573794  55.857827
# GA       40.137802  41.304426  41.565821  44.554129
# HI       51.209661  50.345972  54.156428  53.531792
# IA       75.584828  74.961063  74.154939  68.024664
# ID       53.027985  51.986560  53.686607  54.931054
# IL       36.371117  37.524500  37.027565  37.728502
# IN       64.152076  63.451325  62.328934  48.892526
# KS       41.294752  38.140019  36.940863  36.688565
# KY       56.036107  55.818049  56.006163  55.816450
# LA       70.862856  69.807783  70.216292  70.929656
# MA       71.520249  55.371811  57.018569  53.937469
# MD       43.742851  40.746183        NaN  45.867860
# ME       51.404124  53.327187  50.256313  55.977535
# MI       51.130432  49.013043  38.769891  48.935783
# MN       60.114026  60.391510  59.920387  59.282185
# MO       62.982174  61.302770  49.273795  48.655263
# MS       32.988068  35.144623  38.941098  40.599689
# MT       49.336341  50.161918  49.818299  49.645798
# NC       46.615638  46.319706  46.503288  46.001037
# ND       50.964534  47.415099  45.834004  47.032974
# NE       82.303049  51.264197  51.074023  51.773838
# NH       61.109561  59.097169  58.218749  56.169111
# NJ       50.503777  53.012799  54.913627  57.379347
# NM       27.885960  29.229654        NaN  32.421482
# NV       48.731666  48.439150  46.435742  47.914384
# NY       48.586951  49.800381  53.804687  53.683081
# OH       55.333125  62.025268  63.052108  64.379759
# OK       70.487303  37.511611  34.764656  33.603768
# OR       56.519108  54.725571  55.882203  54.420824
# PA       62.666064  62.715144  62.857883  62.013305
# PR       50.410908  48.255581  45.846350  45.163237
# RI       38.718758  39.896907  35.967319  40.258184
# SC       46.128457  43.241631  44.815996  48.201423
# SD       52.374515  52.405200  53.715763  53.523257
# TN       35.264181  34.665878  34.417951  35.204437
# TX       71.611870  71.735354  45.322279  46.611740
# UT       44.856213  43.879021  45.101607  46.651007
# VA       79.642629  79.863862  79.659995  77.622164
# VI       19.753726  79.591271        NaN  75.279322
# VT       55.577148  51.780163        NaN        NaN
# WA       61.991035  60.814777  60.708902  60.961245
# WI       43.356534  44.450933  42.376477  41.003125
# WV             NaN  47.483840  44.518407        NaN
# WY       56.512613  55.715885  53.048213  55.700880

# %%
score_ct_rla = score_ct_rla.ffill(1).bfill(1)

# %%
score_ct_rla
# Out:
# schl_yr       0910       1011       1112       1213       1314       1415  \
# ST
# AK       81.108949  77.635218  79.319338  77.587169  79.249187  35.183750
# AL       83.852370  85.672088  86.353615  86.393766  42.554322  40.906336
# AR       72.335443  73.507924  80.477681  78.639650  77.123798  34.202721
# AZ       75.010374  77.659493  77.986880  78.896518  79.278068  37.514429
# BI       38.967636  41.196367  41.736723  41.736723  41.736723  41.736723
# CA       54.110620  54.110620  58.252278  56.886987  57.800501  44.335423
# CO       89.948871  89.948871  70.130953  70.192677  69.421333  39.992039
# CT       78.475928  78.475928  80.750481  79.952023  72.013086  55.483732
# DC       48.087516  49.842890  47.214546  51.864083  50.650813  25.703606
# DE       75.492440  62.446111  74.388993  73.540249  73.138697  52.395196
# FL       62.246487  62.278714  57.324525  57.910372  58.400172  53.132251
# GA       90.708428  91.126643  93.645596  94.302272  94.921396  38.688515
# HI       67.370230  66.565095  71.059300  72.175581  69.188882  48.576142
# IA       74.869998  76.462167  71.904097  72.490569  75.775648  76.352525
# ID       87.406236  88.330199  88.910638  88.985416  60.132868  51.108922
# IL       74.834904  75.403183  75.686581  59.149079  57.249562  38.126567
# IN       75.114471  77.696740  78.875674  78.713233  80.064396  68.614585
# KS       86.476418  87.944289  86.898422  84.709193  84.709193  41.957763
# KY       72.061572  72.167629  48.458920  50.640601  54.525473  54.755970
# LA       67.846815  68.793259  73.196048  72.847007  70.653724  71.175024
# MA       69.367518  70.634542  70.403500  69.895116  69.954292  70.240171
# MD       85.005196  85.991408  85.709948  85.469686  82.786549  45.448249
# ME       66.723555  67.204668  68.885653  68.323687  66.710570  48.364306
# MI       83.908734  82.491172  65.687642  66.748972  68.123150  50.026757
# MN       72.638549  74.094759  75.671614  57.931348  59.064940  59.742789
# MO       54.533684  55.176094  55.452974  55.220480  52.767288  59.811677
# MS       51.649199  53.936268  56.983965  59.411783  56.867579  32.783715
# MT       82.916613  83.630835  84.986572  82.911274  22.605375  47.751504
# NC       69.650547  70.468192  73.114902  45.203832  46.035706  46.123529
# ND       76.369306  74.903644  73.833250  73.190572  72.667688  46.291164
# NE       68.715840  71.840135  74.008966  76.642728  77.434781  79.494267
# NH       77.007138  76.770950  78.704789  78.329647  76.860082  58.658777
# NJ       70.072547  70.376982  69.852672  70.440680  70.346688  47.043040
# NM       53.365650  49.882527  50.789663  50.702104  48.969526  26.624297
# NV       67.825986  61.592091  62.782183  64.168392  65.923553  65.923553
# NY       75.717062  59.590317  61.767371  40.529168  36.837726  42.595577
# OH       82.410591  83.177024  83.362828  83.978300  84.129783  74.783603
# OK       67.057131  68.797050  69.227752  70.286246  69.260947  70.341025
# OR       78.047216  81.107544  73.795267  72.468119  72.242758  55.998742
# PA       73.066538  73.995462  72.105670  70.410057  70.268404  62.116770
# PR       40.068441  43.904435  46.025066  47.533700  45.494333  43.117560
# RI       71.202203  72.439045  73.617289  73.788759  73.418064  36.649038
# SC       81.473667  71.526665  72.500357  74.578175  72.268958  41.709143
# SD       75.201233  75.413075  75.404615  74.000299  39.902039  49.276848
# TN       49.190086  52.651596  55.029364  54.127323  51.802009  51.368031
# TX       88.905532  88.512362  88.452133  78.509362  75.275493  73.571078
# UT       80.726351  81.309639  82.876704  82.891421  42.408327  43.631777
# VA       89.005192  88.499058  89.032172  74.750228  74.479352  78.985087
# VI       45.418805  45.418805  45.418805  46.878115  47.310519  17.168451
# VT       70.970652  70.441925  71.549018  70.785067  69.443607  52.017826
# WA       69.626505  69.703964  71.880255  72.633379  73.757749  55.642806
# WI       82.556568  83.898459  36.373997  36.651923  37.027527  52.375044
# WV       42.386076  48.251528  48.658587  48.157894  46.556638  46.026578
# WY       74.657101  74.657101  72.551082  74.368698  53.006243  54.420926
#
# schl_yr       1516       1617       1718       1819
# ST
# AK       35.183750  38.724111  42.734853  39.569760
# AL       38.551373  39.118867  45.944323  45.384786
# AR       48.312131  52.714974  43.995135  44.613275
# AZ       39.857673  41.938555  43.561477  45.342161
# BI       31.354870  30.434659  30.434659  15.884246
# CA       47.663712  48.321486  49.740933  50.784138
# CO       40.127214  42.183351  44.225460  47.237335
# CT       57.665397  56.546266  57.471476  57.553166
# DC       27.114545  30.753574  33.552770  37.892430
# DE       54.828081  54.473289  53.368661  52.349109
# FL       52.351884  53.813461  54.573794  55.857827
# GA       40.137802  41.304426  41.565821  44.554129
# HI       51.209661  50.345972  54.156428  53.531792
# IA       75.584828  74.961063  74.154939  68.024664
# ID       53.027985  51.986560  53.686607  54.931054
# IL       36.371117  37.524500  37.027565  37.728502
# IN       64.152076  63.451325  62.328934  48.892526
# KS       41.294752  38.140019  36.940863  36.688565
# KY       56.036107  55.818049  56.006163  55.816450
# LA       70.862856  69.807783  70.216292  70.929656
# MA       71.520249  55.371811  57.018569  53.937469
# MD       43.742851  40.746183  40.746183  45.867860
# ME       51.404124  53.327187  50.256313  55.977535
# MI       51.130432  49.013043  38.769891  48.935783
# MN       60.114026  60.391510  59.920387  59.282185
# MO       62.982174  61.302770  49.273795  48.655263
# MS       32.988068  35.144623  38.941098  40.599689
# MT       49.336341  50.161918  49.818299  49.645798
# NC       46.615638  46.319706  46.503288  46.001037
# ND       50.964534  47.415099  45.834004  47.032974
# NE       82.303049  51.264197  51.074023  51.773838
# NH       61.109561  59.097169  58.218749  56.169111
# NJ       50.503777  53.012799  54.913627  57.379347
# NM       27.885960  29.229654  29.229654  32.421482
# NV       48.731666  48.439150  46.435742  47.914384
# NY       48.586951  49.800381  53.804687  53.683081
# OH       55.333125  62.025268  63.052108  64.379759
# OK       70.487303  37.511611  34.764656  33.603768
# OR       56.519108  54.725571  55.882203  54.420824
# PA       62.666064  62.715144  62.857883  62.013305
# PR       50.410908  48.255581  45.846350  45.163237
# RI       38.718758  39.896907  35.967319  40.258184
# SC       46.128457  43.241631  44.815996  48.201423
# SD       52.374515  52.405200  53.715763  53.523257
# TN       35.264181  34.665878  34.417951  35.204437
# TX       71.611870  71.735354  45.322279  46.611740
# UT       44.856213  43.879021  45.101607  46.651007
# VA       79.642629  79.863862  79.659995  77.622164
# VI       19.753726  79.591271  79.591271  75.279322
# VT       55.577148  51.780163  51.780163  51.780163
# WA       61.991035  60.814777  60.708902  60.961245
# WI       43.356534  44.450933  42.376477  41.003125
# WV       46.026578  47.483840  44.518407  44.518407
# WY       56.512613  55.715885  53.048213  55.700880

# %%
score_ct_mth = score_ct_mth.ffill(1).bfill(1)

# %%
score_ct_mth
# Out:
# schl_yr       0910       1011       1112       1213       1314       1415  \
# ST
# AK       70.859658  68.372572  68.235698  69.050183  67.987156  31.400648
# AL       79.484940  81.305444  82.514680  81.130959  38.198251  39.614424
# AR       75.881971  76.605977  78.744055  75.699942  73.296797  24.952473
# AZ       60.180705  62.049594  63.258925  63.753082  63.332630  37.918895
# BI       30.749464  32.922968  35.453569  35.453569  35.453569  35.453569
# CA       56.102139  56.102139  59.431748  59.530465  62.745855  34.184505
# CO       83.521641  83.521641  56.806091  57.475641  56.898892  30.308582
# CT       84.328155  84.328155  84.182845  82.446999  73.219098  39.182264
# DC       48.237258  49.233909  50.482521  55.104467  55.170301  23.067708
# DE       71.751860  62.647846  73.304570  70.621784  69.732846  39.285110
# FL       68.345109  68.558749  56.784752  58.047173  59.568160  53.346266
# GA       80.916762  84.551916  81.430344  83.056965  79.242463  37.996659
# HI       48.728619  54.684585  59.204462  59.446540  58.099206  41.031913
# IA       77.386288  78.201755  76.904341  76.872494  79.273455  78.978027
# ID       80.480662  80.333437  80.444119  80.805082  48.103918  39.308812
# IL       80.836503  81.032819  81.141825  58.502007  59.323377  28.515904
# IN       76.801024  80.088960  80.485318  81.917391  83.078980  64.227141
# KS       83.232454  84.983231  84.843006  78.401985  78.401985  32.843805
# KY       64.252225  66.144517  40.734577  41.731569  46.072425  45.060858
# LA       68.117266  67.920852  72.441629  68.340529  69.205921  61.726400
# MA       59.401154  59.756300  59.851279  61.905425  60.953887  61.785487
# MD       81.096046  81.586148  83.252316  80.018275  72.592960  38.745233
# ME       59.870067  59.366892  61.329370  60.649733  59.108536  36.945696
# MI       80.562187  82.468935  38.714175  41.868132  41.729173  37.909009
# MN       64.910480  56.365148  61.955742  60.736885  60.986025  60.676563
# MO       53.678305  54.931686  55.456399  53.678963  51.780903  43.985996
# MS       60.596227  62.626114  64.846901  68.442923  65.116969  27.065670
# MT       66.471692  67.046631  67.348101  65.411366  22.338048  39.164899
# NC       81.277894  82.466153  82.755027  41.955837  42.551385  43.924557
# ND       77.293703  76.058440  76.622506  75.209026  74.270462  40.471389
# NE       92.030590  62.989930  67.243251  69.110962  71.484571  72.132176
# NH       66.328119  65.980477  67.231577  67.282882  64.975216  46.435611
# NJ       73.860074  76.100702  76.313224  75.475147  75.310348  36.119124
# NM       42.540265  41.882371  42.914385  42.134998  40.864663  17.829114
# NV       65.124738  68.496150  71.321377  61.044965  62.398160  62.398160
# NY       87.922943  68.686147  70.006787  40.618279  41.153808  50.575033
# OH       76.851533  77.876669  78.603048  77.230579  77.464972  67.988701
# OK       65.989154  68.136069  68.599025  69.872595  65.761400  67.273618
# OR       71.342446  63.539356  64.588208  63.584870  63.385939  42.261743
# PA       76.458222  76.864208  75.119384  73.505927  72.008309  43.493308
# PR       23.973360  25.765151  27.875769  27.593483  29.003209  28.676256
# RI       55.628678  56.883815  57.498367  58.121375  56.691768  25.531110
# SC       78.259376  70.724738  71.423205  70.241160  68.692311  51.114599
# SD       76.570979  76.542038  75.843103  73.616743  40.205549  41.476032
# TN       36.882633  44.107048  51.386621  54.182599  52.559368  57.583299
# TX       83.892792  84.357946  83.411623  77.937383  76.310557  73.041229
# UT       69.795390  73.050918  74.807254  77.157632  44.308928  44.880539
# VA       87.459030  86.412903  68.387697  70.921521  74.074360  79.161614
# VI       55.366823  55.366823  55.366823  55.085796  53.444221   6.857777
# VT       59.684325  58.416066  59.347536  59.062865  56.330451  39.357165
# WA       54.072570  60.079847  63.476061  64.206981  65.288052  49.391501
# WI       78.244090  78.122245  48.709794  48.581488  49.120258  44.345862
# WV       43.601362  44.199421  48.137275  45.709957  42.164737  29.697224
# WY       74.788826  74.788826  73.837350  77.057167  45.101725  47.438748
#
# schl_yr       1516       1617       1718       1819
# ST
# AK       31.400648  32.355879  37.150127  36.121113
# AL       42.977884  43.858263  47.076458  46.553027
# AR       43.655112  47.232320  46.989955  47.225744
# AZ       38.965315  42.266753  44.634815  44.352047
# BI       24.798309  25.364807  25.364807  11.152058
# CA       36.592254  37.644323  38.826843  39.536602
# CO       32.676182  32.758033  34.749892  35.174031
# CT       43.751497  45.794838  46.626140  47.473211
# DC       25.187723  27.524723  29.812009  31.297636
# DE       42.708427  43.441495  41.942924  41.709640
# FL       53.774196  56.603830  58.134524  58.822935
# GA       40.704878  40.719040  42.169775  43.679356
# HI       41.732793  41.882922  41.924712  42.216975
# IA       78.305259  77.246971  75.756131  69.467172
# ID       41.707336  41.938183  43.800863  44.513301
# IL       30.604804  31.869135  31.817523  32.315828
# IN       54.909368  54.441930  54.256543  45.294958
# KS       34.372293  34.023572  33.007584  32.764439
# KY       48.671446  46.857433  46.828156  46.136805
# LA       64.444412  63.285713  64.132963  64.681139
# MA       63.819801  52.807874  52.361001  50.668174
# MD       42.149859  41.043852  41.043852  37.618260
# ME       39.443399  39.526674  37.163128  35.757118
# MI       39.175174  38.677201  33.107373  39.307563
# MN       60.014314  59.045371  57.332676  55.208704
# MO       47.755304  47.130078  42.065508  41.871300
# MS       31.202348  36.655263  42.343072  46.046890
# MT       41.415495  40.552332  40.790967  41.275235
# NC       46.660836  47.247558  42.332195  42.097673
# ND       41.783560  38.749787  43.707669  43.979665
# NE       72.602067  69.164375  50.679848  51.976974
# NH       49.140308  48.680795  47.910386  47.852858
# NJ       39.760117  40.579341  42.156316  43.978145
# NM       20.430462  20.175522  21.841391  20.119597
# NV       38.720801  40.339542  35.046705  35.816257
# NY       51.629655  51.805367  53.685870  55.312073
# OH       60.731690  62.866966  61.704335  62.523006
# OK       67.506485  34.545639  30.826433  32.149130
# OR       42.456545  41.715119  41.275228  40.155083
# PA       45.986949  45.742812  45.178847  44.946060
# PR       32.380962  31.367102  32.735135  30.404368
# RI       30.503027  32.464466  27.775205  30.071566
# SC       45.876464  44.289489  45.387287  46.256600
# SD       44.373455  46.190148  46.557718  45.526961
# TN       15.828271  35.618577  34.906181  38.922963
# TX       75.159988  77.939991  48.398477  50.543014
# UT       47.416871  46.627842  46.625132  44.897697
# VA       79.596716  72.451244  72.451244  82.099683
# VI        6.871337  91.171131  91.171131  89.899965
# VT       44.385896  41.653279  41.653279  41.653279
# WA       51.204995  51.304072  50.915599  50.294275
# WI       42.179684  42.280859  43.018989  41.939935
# WV       32.723317  34.792266  36.998670  38.187403
# WY       50.405466  50.255002  49.214983  51.250509

# %%
#take avg of math and reading/languagae arts scores
score_ct_mth_rla = (score_ct_mth + score_ct_rla)/2

# %%
score_ct_mth_rla
# Out:
# schl_yr       0910       1011       1112       1213       1314       1415  \
# ST
# AK       75.984303  73.003895  73.777518  73.318676  73.618172  33.292199
# AL       81.668655  83.488766  84.434147  83.762363  40.376287  40.260380
# AR       74.108707  75.056951  79.610868  77.169796  75.210298  29.577597
# AZ       67.595540  69.854543  70.622902  71.324800  71.305349  37.716662
# BI       34.858550  37.059668  38.595146  38.595146  38.595146  38.595146
# CA       55.106379  55.106379  58.842013  58.208726  60.273178  39.259964
# CO       86.735256  86.735256  63.468522  63.834159  63.160112  35.150310
# CT       81.402042  81.402042  82.466663  81.199511  72.616092  47.332998
# DC       48.162387  49.538400  48.848533  53.484275  52.910557  24.385657
# DE       73.622150  62.546979  73.846782  72.081017  71.435772  45.840153
# FL       65.295798  65.418731  57.054639  57.978773  58.984166  53.239258
# GA       85.812595  87.839279  87.537970  88.679619  87.081930  38.342587
# HI       58.049424  60.624840  65.131881  65.811061  63.644044  44.804027
# IA       76.128143  77.331961  74.404219  74.681531  77.524551  77.665276
# ID       83.943449  84.331818  84.677378  84.895249  54.118393  45.208867
# IL       77.835704  78.218001  78.414203  58.825543  58.286470  33.321235
# IN       75.957747  78.892850  79.680496  80.315312  81.571688  66.420863
# KS       84.854436  86.463760  85.870714  81.555589  81.555589  37.400784
# KY       68.156899  69.156073  44.596748  46.186085  50.298949  49.908414
# LA       67.982040  68.357056  72.818838  70.593768  69.929822  66.450712
# MA       64.384336  65.195421  65.127390  65.900270  65.454089  66.012829
# MD       83.050621  83.788778  84.481132  82.743981  77.689754  42.096741
# ME       63.296811  63.285780  65.107511  64.486710  62.909553  42.655001
# MI       82.235461  82.480053  52.200908  54.308552  54.926161  43.967883
# MN       68.774515  65.229954  68.813678  59.334117  60.025482  60.209676
# MO       54.105995  55.053890  55.454687  54.449721  52.274095  51.898836
# MS       56.122713  58.281191  60.915433  63.927353  60.992274  29.924693
# MT       74.694152  75.338733  76.167336  74.161320  22.471711  43.458201
# NC       75.464220  76.467172  77.934964  43.579834  44.293546  45.024043
# ND       76.831504  75.481042  75.227878  74.199799  73.469075  43.381277
# NE       80.373215  67.415032  70.626109  72.876845  74.459676  75.813221
# NH       71.667628  71.375713  72.968183  72.806264  70.917649  52.547194
# NJ       71.966311  73.238842  73.082948  72.957914  72.828518  41.581082
# NM       47.952958  45.882449  46.852024  46.418551  44.917095  22.226706
# NV       66.475362  65.044121  67.051780  62.606679  64.160857  64.160857
# NY       81.820002  64.138232  65.887079  40.573724  38.995767  46.585305
# OH       79.631062  80.526847  80.982938  80.604440  80.797377  71.386152
# OK       66.523143  68.466560  68.913388  70.079421  67.511173  68.807321
# OR       74.694831  72.323450  69.191737  68.026495  67.814349  49.130242
# PA       74.762380  75.429835  73.612527  71.957992  71.138357  52.805039
# PR       32.020901  34.834793  36.950417  37.563592  37.248771  35.896908
# RI       63.415440  64.661430  65.557828  65.955067  65.054916  31.090074
# SC       79.866522  71.125701  71.961781  72.409667  70.480634  46.411871
# SD       75.886106  75.977556  75.623859  73.808521  40.053794  45.376440
# TN       43.036359  48.379322  53.207992  54.154961  52.180689  54.475665
# TX       86.399162  86.435154  85.931878  78.223372  75.793025  73.306153
# UT       75.260871  77.180279  78.841979  80.024526  43.358627  44.256158
# VA       88.232111  87.455980  78.709935  72.835874  74.276856  79.073351
# VI       50.392814  50.392814  50.392814  50.981956  50.377370  12.013114
# VT       65.327489  64.428995  65.448277  64.923966  62.887029  45.687495
# WA       61.849538  64.891905  67.678158  68.420180  69.522901  52.517153
# WI       80.400329  81.010352  42.541895  42.616706  43.073893  48.360453
# WV       42.993719  46.225475  48.397931  46.933926  44.360688  37.861901
# WY       74.722964  74.722964  73.194216  75.712933  49.053984  50.929837
#
# schl_yr       1516       1617       1718       1819
# ST
# AK       33.292199  35.539995  39.942490  37.845437
# AL       40.764629  41.488565  46.510390  45.968907
# AR       45.983621  49.973647  45.492545  45.919510
# AZ       39.411494  42.102654  44.098146  44.847104
# BI       28.076590  27.899733  27.899733  13.518152
# CA       42.127983  42.982905  44.283888  45.160370
# CO       36.401698  37.470692  39.487676  41.205683
# CT       50.708447  51.170552  52.048808  52.513188
# DC       26.151134  29.139149  31.682389  34.595033
# DE       48.768254  48.957392  47.655792  47.029374
# FL       53.063040  55.208645  56.354159  57.340381
# GA       40.421340  41.011733  41.867798  44.116742
# HI       46.471227  46.114447  48.040570  47.874384
# IA       76.945044  76.104017  74.955535  68.745918
# ID       47.367660  46.962371  48.743735  49.722177
# IL       33.487960  34.696817  34.422544  35.022165
# IN       59.530722  58.946628  58.292738  47.093742
# KS       37.833522  36.081796  34.974224  34.726502
# KY       52.353777  51.337741  51.417160  50.976627
# LA       67.653634  66.546748  67.174628  67.805398
# MA       67.670025  54.089842  54.689785  52.302821
# MD       42.946355  40.895018  40.895018  41.743060
# ME       45.423762  46.426931  43.709720  45.867327
# MI       45.152803  43.845122  35.938632  44.121673
# MN       60.064170  59.718441  58.626532  57.245444
# MO       55.368739  54.216424  45.669651  45.263281
# MS       32.095208  35.899943  40.642085  43.323290
# MT       45.375918  45.357125  45.304633  45.460517
# NC       46.638237  46.783632  44.417741  44.049355
# ND       46.374047  43.082443  44.770836  45.506319
# NE       77.452558  60.214286  50.876935  51.875406
# NH       55.124935  53.888982  53.064568  52.010985
# NJ       45.131947  46.796070  48.534971  50.678746
# NM       24.158211  24.702588  25.535522  26.270540
# NV       43.726233  44.389346  40.741223  41.865321
# NY       50.108303  50.802874  53.745278  54.497577
# OH       58.032407  62.446117  62.378221  63.451382
# OK       68.996894  36.028625  32.795544  32.876449
# OR       49.487826  48.220345  48.578715  47.287954
# PA       54.326506  54.228978  54.018365  53.479682
# PR       41.395935  39.811341  39.290742  37.783802
# RI       34.610892  36.180687  31.871262  35.164875
# SC       46.002461  43.765560  45.101642  47.229012
# SD       48.373985  49.297674  50.136741  49.525109
# TN       25.546226  35.142227  34.662066  37.063700
# TX       73.385929  74.837672  46.860378  48.577377
# UT       46.136542  45.253431  45.863369  45.774352
# VA       79.619672  76.157553  76.055619  79.860923
# VI       13.312532  85.381201  85.381201  82.589643
# VT       49.981522  46.716721  46.716721  46.716721
# WA       56.598015  56.059425  55.812251  55.627760
# WI       42.768109  43.365896  42.697733  41.471530
# WV       39.374947  41.138053  40.758539  41.352905
# WY       53.459040  52.985443  51.131598  53.475694

# %%
from sklearn.cluster import KMeans

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
y_pred = kmeans.fit_predict(score_ct_mth)

# %%
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(score_ct_rla)
                for k in range(1, 30)]

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = [silhouette_score(score_ct_rla, model.labels_)
                     for model in kmeans_per_k[1:]]

# %%
silhouette_scores
# Out:
# [0.33977097842991016,
#  0.27726643501364634,
#  0.2356154816502484,
#  0.23064005386034434,
#  0.26406540957755814,
#  0.24502276061798936,
#  0.25897497780878626,
#  0.2492526493859493,
#  0.2551847239517918,
#  0.24212365069461944,
#  0.2510435135873206,
#  0.23235927021223032,
#  0.2326124190778358,
#  0.2197943143624952,
#  0.22106261165847527,
#  0.22690802709097002,
#  0.2177113296288736,
#  0.22064164853552418,
#  0.2254985116788139,
#  0.2230178053944556,
#  0.23271505241204893,
#  0.2330344304769791,
#  0.24192318527613976,
#  0.24333157659142002,
#  0.2463035518132608,
#  0.2507854437404475,
#  0.24010114682007758,
#  0.23223686753380496]

# %%
from sklearn.manifold import TSNE

# %%
tsne_rla  = pd.DataFrame(TSNE(n_components=2,perplexity=4).fit_transform(score_ct_mth_rla),columns=['x','y'])

# %%
sns.scatterplot(x=tsne_rla.x,y=tsne_rla.y)

# %%
def tsne(data,perp):
    
    tsne_data  = pd.DataFrame(TSNE(n_components=2,perplexity=perp,random_state=13).fit_transform(data),columns=['x','y'])
    
    return sns.scatterplot(x=tsne_data.x,y=tsne_data.y)

# %%
tsne(score_ct_mth_rla,2)

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=30, min_samples=3)

# %%
def dbscanplot(data,eps,mins):
    
    dbscan = DBSCAN(eps=eps, min_samples=mins)
    data['dbscan'] = dbscan.fit_predict(score_ct_mth)
      
    data = data.reset_index().set_index(['ST','dbscan'])
    
    data = data.stack().reset_index()
    
    data.columns = ['ST','dbscan','schl_yr','pctprof']
    
    datagb = data[['ST','dbscan']].groupby('dbscan').nunique()['ST']
    
    return sns.catplot(data=data, x='schl_yr', y='pctprof',
                       col='dbscan', kind='box', col_wrap=2,
                       color='grey' ),pd.DataFrame(datagb)

# %%
def dbscandata(data,eps,mins):
    
    dbscan = DBSCAN(eps=eps, min_samples=mins)
    data['dbscan'] = dbscan.fit_predict(score_ct_mth)
      
    data = data.reset_index().set_index(['ST','dbscan'])
    
    data = data.stack().reset_index()
    
    data.columns = ['ST','dbscan','schl_yr','pctprof']
       
    return data

# %%
dbscanplot(score_ct_mth_rla,18,2)
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x1fae215e640>,
#          ST
#  dbscan
#  -1      23
#   0      21
#   1       5
#   2       2
#   3       3)

# %%
dbscandata = dbscandata(score_ct_mth,18,2)

# %%
dbscandata['ol'] = dbscandata.dbscan == -1

# %%
il = dbscandata[dbscandata['dbscan'] != -1]
ol = dbscandata[dbscandata['dbscan'] == -1]

# %%
dbscan_gb = pd.DataFrame(dbscandata[['ST','dbscan']].groupby('dbscan').nunique()['ST']).reset_index()

# %%
dbscan_gb.dbscan = 'cluster_' + dbscan_gb.dbscan.astype(str)

# %%
fig, lineplot = plt.subplots(figsize = (16,6))

ax = sns.barplot(y=dbscan_gb.dbscan.astype(str),x=dbscan_gb.ST,color='#9d94ba')

ax.set(title='Distribution of Clusters')

# label each bar in barplot
for p in ax.patches:
 height = p.get_height() # height of each horizontal bar is the same
 width = p.get_width() # width (average number of passengers)
 # adding text to each bar
 ax.text(x = width+.05, # x-coordinate position of data label, padded 3 to right of bar
 y = p.get_y()+(height/2), # # y-coordinate position of data label, padded to be in the middle of the bar
 s = '{:.0f}'.format(width), # data label, formatted to ignore decimals
 va = 'center') # sets vertical alignment (va) to center

# %%
fig, lineplot = plt.subplots(figsize = (18,16))

sns.lineplot(y=il.pctprof,x=il.schl_yr,hue=il.dbscan,palette="Set2",ci=95,err_style='band')

# %%
fig, lineplot = plt.subplots(figsize = (18,16))

sns.lineplot(y=ol.pctprof,x=ol.schl_yr,hue=ol.dbscan,palette="Set2",ci=95\
             ,err_style='band')

# %%
grid = sns.FacetGrid(data = dbscandata[dbscandata.dbscan == 0], col="ST",height=4,col_wrap=4)
grid.map(sns.lineplot,'schl_yr','pctprof')

# %%
grid = sns.FacetGrid(data = dbscandata[dbscandata.dbscan == 1], col="ST",height=4,col_wrap=4)
grid.map(sns.lineplot,'schl_yr','pctprof')

# %%
grid = sns.FacetGrid(data = dbscandata[dbscandata.dbscan == 2], col="ST",height=4,col_wrap=4)
grid.map(sns.lineplot,'schl_yr','pctprof')

# %%
grid = sns.FacetGrid(data = dbscandata[dbscandata.dbscan == 3], col="ST",height=4,col_wrap=4)
grid.map(sns.lineplot,'schl_yr','pctprof')

# %%
grid = sns.FacetGrid(data = dbscandata[dbscandata.dbscan == -1], col="ST",height=4,col_wrap=4)
grid.map(sns.lineplot,'schl_yr','pctprof')

# %%
from sklearn import metrics

# %%
from scipy.spatial.distance import euclidean

# %%
from scipy.spatial.distance import euclidean
from DBCV import DBCV

# %%
dbscan15_2_sc = DBCV(score_ct_mth_rla.drop('dbscan',axis=1).values, score_ct_mth_rla.dbscan, dist_function=euclidean)

# %%
dbscan15_2_sc
# Out:
# -0.21795742651436345

# %%
eps_st = 10
eps = [10]

# %%
while eps_st < 30:
    eps_st = eps_st + 1
    
    eps.append(eps_st)

# %%
nh_st = 2
nh = [2]

# %%
while nh_st < 10:
    nh_st = nh_st + 1
    
    nh.append(nh_st)

# %%
#score_ct_mth_rla.drop('dbscan',axis=1)

results = []

#loop for dbscan gridsearch
for e in eps:
    for n in nh:
        
        #perform clustering with parameters
        dbscan = DBSCAN(eps=e, min_samples=n)
        labels = dbscan.fit_predict(score_ct_mth_rla.drop('dbscan',axis=1))
        
        #calculate dbcv score
        score = DBCV(score_ct_mth_rla.drop('dbscan',axis=1).values, labels, dist_function=euclidean)
        
        result = [e,n,score]
        
        results.append(result)
# Out:
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator
# C:\Users\henry\anaconda3\lib\site-packages\DBCV\DBCV.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   cluster_validity = numerator / denominator

# %%
pd.DataFrame(results,columns = ['eps','min_samples','dbcv']).dropna().sort_values(by='dbcv',ascending=False)
# Out:
#      eps  min_samples      dbcv
# 181   30            3  0.675207
# 180   30            2  0.675207
# 182   30            4  0.377884
# 135   25            2  0.034903
# 126   24            2 -0.048386
# ..   ...          ...       ...
# 39    14            5 -0.738212
# 40    14            6 -0.773042
# 30    13            5 -0.773042
# 29    13            4 -0.773042
# 20    12            4 -0.784839
#
# [153 rows x 3 columns]
