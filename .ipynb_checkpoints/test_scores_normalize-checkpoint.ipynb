# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_columns', 500)

# %%
os.chdir(r'C:\Users\henry\OneDrive\Documents\school_performance_data\test_scores\test_scores_converted')

# %%
math0910 = pd.read_csv('math-achievement-sch-sy2009-10_out.csv')

# %%
math0910
# Out:
#        Unnamed: 0      STNAM  FIPST    leaid  \
# 0               0    ALABAMA      1   100005
# 1               1    ALABAMA      1   100005
# 2               2    ALABAMA      1   100005
# 3               3    ALABAMA      1   100005
# 4               4    ALABAMA      1   100006
# ...           ...        ...    ...      ...
# 91200       91200  WISCONSIN     55  5517160
# 91201       91201  WISCONSIN     55  5517190
# 91202       91202  WISCONSIN     55  5517190
# 91203       91203  WISCONSIN     55  5517190
# 91204       91204  WISCONSIN     55  5517220
#
#                                        leanm       NCESSCH  \
# 0                           Albertville City   10000500870
# 1                           Albertville City   10000500871
# 2                           Albertville City   10000500879
# 3                           Albertville City   10000500889
# 4                            Marshall County   10000600193
# ...                                      ...           ...
# ...

# %%
os.chdir(r'C:\Users\henry\OneDrive\Documents\school_performance_data\school_dem_info')

# %%
import glob
zips = glob.glob('*.zip')

# %%
zips
# Out:
# ['ccd_sch_029_1516_w_1a_011717_csv.zip',
#  'ccd_sch_029_1617_w_0e_050317_csv.zip',
#  'ccd_sch_029_1718_w_0a_03302018_csv.zip',
#  'ccd_sch_029_1718_w_1a_083118.zip',
#  'ccd_sch_029_1819_w_0a_04082019_csv.zip',
#  'ccd_sch_033_1516_w_1a_011717_csv.zip',
#  'ccd_sch_033_1617_l_1a_112117_csv.zip',
#  'ccd_sch_033_1718_l_1a_083118.zip',
#  'ccd_sch_033_1819_l_1a_091019.zip',
#  'ccd_sch_052_1516_w_1a_011717_csv.zip',
#  'ccd_sch_052_1617_l_1a_11212017_csv.zip',
#  'CCD_SCH_059_1516_W_1a_011717_csv.zip',
#  'CCD_sch_059_1617_l_1a_11212017_csv.zip',
#  'ccd_sch_059_1819_l_1a_091019.zip',
#  'ccd_sch_129_1516_w_1a_011717_csv.zip',
#  'ccd_sch_129_1617_w_1a_11212017_csv.zip',
#  'ccd_sch_129_1819_w_1a_091019.zip',
#  'sc091a_txt.zip',
#  'sc101a_txt.zip',
#  'sc121a_documentation.zip',
#  'sc121a_supp_txt.zip',
#  'sc131a_Documentation.zip',
#  'Sch14pre_txt.zip']

# %%
from zipfile import ZipFile

# %%
def extract_zip(zipfile,path):
    '''Open and extract contents of a zipfile.'''
    
    file = ZipFile(zipfile,'r')
    
    file.extractall(path)

# %%
path = r'C:\Users\henry\OneDrive\Documents\school_performance_data\school_dem_info\school_dem_data_files'

#extract all of the zip files with demographic information
extractzip = [extract_zip(file,path) for file in zips]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
os.chdir(r'C:\Users\henry\OneDrive\Documents\school_performance_data\school_dem_info\school_dem_data_files')

# %%
school_dem0910 = pd.read_table('sc091a.txt',delim_whitespace=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-50-c106ba22140c> in <module>
# ----> 1 school_dem0910 = pd.read_table('sc091a.txt',delim_whitespace=True)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
class test_data_normalizer:
    '''Class to normalize test score data for schools.'''
